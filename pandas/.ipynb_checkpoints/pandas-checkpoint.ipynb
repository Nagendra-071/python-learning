# %%
import numpy as np 
import pandas as pd

# %%
dict1={
    "name":['harry','aj','pj','dj'],
    "marks":[12,25,4,62],
    "city":['kanpur','rampur','us','uae']
      }

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#     name  marks    city
# 0  harry     12  kanpur
# 1     aj     25  rampur
# 2     pj      4      us
# 3     dj     62     uae

# %%
df.to_csv("test.csv")

# %%
df.to_csv("test2.csv",index=False)

# %%
df.head(2)
# Out:
#     name  marks    city
# 0  harry     12  kanpur
# 1     aj     25  rampur

# %%
df.tail(2)
# Out:
#   name  marks city
# 2   pj      4   us
# 3   dj     62  uae

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   25.750000
# std    25.669372
# min     4.000000
# 25%    10.000000
# 50%    18.500000
# 75%    34.250000
# max    62.000000

# %%
ex=pd.read_csv("test.csv")

# %%
ex
# Out:
#    Unnamed: 0   name  marks    city
# 0           0  harry     12  kanpur
# 1           1     aj     25  rampur
# 2           2     pj      4      us
# 3           3     dj     62     uae

# %%
ex["city"]
# Out:
# 0    kanpur
# 1    rampur
# 2        us
# 3       uae
# Name: city, dtype: object

# %%
ex.index=["one","two","three","four"]

# %%
ex
# Out:
#        Unnamed: 0   name  marks    city
# one             0  harry     12  kanpur
# two             1     aj     25  rampur
# three           2     pj      4      us
# four            3     dj     62     uae
